# %%
#Priya Notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import scipy.stats as st

# Food Desert Data References
desert = "./Priya's Resources/Food Deserts/food_access_research_atlas.csv"
variable = "./Priya's Resources/Food Deserts/food_access_variable_lookup.csv"

#Farmers Market Data References
farmers_market = "./Priya's Resources/Farmers Markets/farmers_markets_from_usda.csv"
county_info = "./Priya's Resources/Farmers Markets/wiki_county_info.csv" 


desert_df = pd.read_csv(desert)
desert_var = pd.read_csv(variable)
farmers_df = pd.read_csv(farmers_market)
county_df = pd.read_csv(county_info)

# %% [markdown]
# # Farmers Market Data Overview / Cleaning

# %%
farmers_df.head()
# Out:
#       FMID                                        MarketName  \
# 0  1018261   Caledonia Farmers Market Association - Danville
# 1  1018318                 Stearns Homestead Farmers' Market
# 2  1009364                 106 S. Main Street Farmers Market
# 3  1010691               10th Steet Community Farmers Market
# 4  1002454                              112st Madison Avenue
#
#                                              Website  \
# 0  https://sites.google.com/site/caledoniafarmers...
# 1                    http://www.StearnsHomestead.com
# 2             http://thetownofsixmile.wordpress.com/
# 3                                                NaN
# 4                                                NaN
#
#                                             Facebook Twitter Youtube  \
# 0  https://www.facebook.com/Danville.VT.Farmers.M...     NaN     NaN
# 1                      StearnsHomesteadFarmersMarket     NaN     NaN
# 2                                                NaN     NaN     NaN
# 3                                                NaN     NaN     NaN
# 4                                                NaN     NaN     NaN
#
#                                           OtherMedia                  street  \
# 0                                                NaN                     NaN
# 1                                                NaN         6975 Ridge Road
# 2                                                NaN      106 S. Main Street
# 3  http://agrimissouri.com/mo-grown/grodetail.php...  10th Street and Poplar
# 4                                                NaN    112th Madison Avenue
#
#        city     County       ...        Coffee Beans Fruits Grains Juices  \
# 0  Danville  Caledonia       ...             Y     Y      Y      N      N
# 1    Parma    Cuyahoga       ...             N     N      Y      N      N
# 2  Six Mile    Pickens       ...           NaN   NaN    NaN    NaN    NaN
# 3    Lamar      Barton       ...             N     N      Y      N      N
# 4  New York   New York       ...             N     N      N      N      N
#
#   Mushrooms PetFood Tofu WildHarvested       updateTime
# 0         Y       Y    N             N  6/20/2017 22:43
# 1         N       N    N             N  6/21/2017 17:15
# 2       NaN     NaN  NaN           NaN             2013
# 3         N       N    N             N  10/28/2014 9:49
# 4         N       N    N             N   3/1/2012 10:38
#
# [5 rows x 59 columns]

# %%
farmers_df.columns
# Out:
# Index(['FMID', 'MarketName', 'Website', 'Facebook', 'Twitter', 'Youtube',
#        'OtherMedia', 'street', 'city', 'County', 'State', 'zip', 'Season1Date',
#        'Season1Time', 'Season2Date', 'Season2Time', 'Season3Date',
#        'Season3Time', 'Season4Date', 'Season4Time', 'x', 'y', 'Location',
#        'Credit', 'WIC', 'WICcash', 'SFMNP', 'SNAP', 'Organic', 'Bakedgoods',
#        'Cheese', 'Crafts', 'Flowers', 'Eggs', 'Seafood', 'Herbs', 'Vegetables',
#        'Honey', 'Jams', 'Maple', 'Meat', 'Nursery', 'Nuts', 'Plants',
#        'Poultry', 'Prepared', 'Soap', 'Trees', 'Wine', 'Coffee', 'Beans',
#        'Fruits', 'Grains', 'Juices', 'Mushrooms', 'PetFood', 'Tofu',
#        'WildHarvested', 'updateTime'],
#       dtype='object')

# %%
county_df = county_df.rename(columns={"county":"County"})
county_df.head()
# Out:
#   number             County       State per capita income  \
# 0      1    New York County    New York          $62,498
# 1      2          Arlington    Virginia          $62,018
# 2      3  Falls Church City    Virginia          $59,088
# 3      4              Marin  California          $56,791
# 4      5    Alexandria City    Virginia          $54,608
#
#   median household income median family income population number of households
# 0                $69,659              $84,627   1,605,272              736,192
# 1               $103,208             $139,244     214,861               94,454
# 2               $120,000             $152,857      12,731                5,020
# 3                $90,839             $117,357     254,643              102,912
# 4                $85,706             $107,511     143,684               65,369

# %%
farmers_df.columns
# Out:
# Index(['FMID', 'MarketName', 'Website', 'Facebook', 'Twitter', 'Youtube',
#        'OtherMedia', 'street', 'city', 'County', 'State', 'zip', 'Season1Date',
#        'Season1Time', 'Season2Date', 'Season2Time', 'Season3Date',
#        'Season3Time', 'Season4Date', 'Season4Time', 'x', 'y', 'Location',
#        'Credit', 'WIC', 'WICcash', 'SFMNP', 'SNAP', 'Organic', 'Bakedgoods',
#        'Cheese', 'Crafts', 'Flowers', 'Eggs', 'Seafood', 'Herbs', 'Vegetables',
#        'Honey', 'Jams', 'Maple', 'Meat', 'Nursery', 'Nuts', 'Plants',
#        'Poultry', 'Prepared', 'Soap', 'Trees', 'Wine', 'Coffee', 'Beans',
#        'Fruits', 'Grains', 'Juices', 'Mushrooms', 'PetFood', 'Tofu',
#        'WildHarvested', 'updateTime'],
#       dtype='object')

# %%
farmers_access_df = farmers_df.loc[:,['MarketName','city', 'County', 'State',
                                      'WIC', 'WICcash', 'SFMNP','SNAP']]
farmers_access_df.head()
# Out:
#                                          MarketName      city     County  \
# 0   Caledonia Farmers Market Association - Danville  Danville  Caledonia
# 1                 Stearns Homestead Farmers' Market    Parma    Cuyahoga
# 2                 106 S. Main Street Farmers Market  Six Mile    Pickens
# 3               10th Steet Community Farmers Market    Lamar      Barton
# 4                              112st Madison Avenue  New York   New York
#
#             State WIC WICcash SFMNP SNAP
# 0         Vermont   Y       N     Y    N
# 1            Ohio   N       N     Y    N
# 2  South Carolina   N       N     N    N
# 3        Missouri   N       N     N    N
# 4        New York   N       Y     Y    N

# %%
access_df = pd.merge(farmers_access_df,county_df, how = "outer",on = "County")
access_df = access_df[access_df.MarketName.notnull()]
access_df = access_df.dropna()
cleaned_access = access_df.drop_duplicates("MarketName").reset_index()
cleaned_access = cleaned_access[["MarketName","city","County","State_x","WIC","WICcash","SFMNP","SNAP","per capita income","median household income","median family income","population","number of households"]]
cleaned_access = cleaned_access.rename(columns={
    "city":"City",
    "State_x":"State",
    "per capita income": "Income Per Capita",
    "median household income": "Median Household Income",
    "median family income": "Median Family Income",
    "population":"Population",
    "number of households":"Number of Households"
})
cleaned_access = cleaned_access[cleaned_access.Population.notnull()]
cleaned_access = cleaned_access[cleaned_access["Income Per Capita"].notnull()]
cleaned_access["Income Per Capita"]= cleaned_access["Income Per Capita"].str.replace(',', '').str.replace('$','').astype(int)
cleaned_access["Median Household Income"]= cleaned_access["Median Household Income"].str.replace(',', '').str.replace('$','').astype(int)
cleaned_access["Median Family Income"]= cleaned_access["Median Family Income"].str.replace(',', '').str.replace('$','').astype(int)
cleaned_access["Population"]= cleaned_access["Population"].str.replace(',', '').astype(int)
cleaned_access["Number of Households"]= cleaned_access["Number of Households"].str.replace(',', '').astype(int)
cleaned_access.head()
# Out:
#                                          MarketName            City  \
# 0   Caledonia Farmers Market Association - Danville        Danville
# 1   Caledonia Farmers Market Association - Saturday  St. Johnsbury
# 2     Caledonia Farmers Market Association - Winter   St. Johnsbury
# 3                    Groton Growers Farmers' Market          Groton
# 4                          Hardwick Farmers' Market        Hardwick
#
#       County    State WIC WICcash SFMNP SNAP  Income Per Capita  \
# 0  Caledonia  Vermont   Y       N     Y    N              23584
# 1  Caledonia  Vermont   Y       N     Y    Y              23584
# 2  Caledonia  Vermont   N       N     N    N              23584
# 3  Caledonia  Vermont   Y       N     Y    Y              23584
# 4  Caledonia  Vermont   Y       Y     Y    Y              23584
#
#    Median Household Income  Median Family Income  Population  \
# 0                    45395                 54941       31157
# 1                    45395                 54941       31157
# 2                    45395                 54941       31157
# 3                    45395                 54941       31157
# 4                    45395                 54941       31157
#
#    Number of Households
# 0                 12491
# 1                 12491
# 2                 12491
# 3                 12491
# 4                 12491

# %%
print(f"Total Farmers Markets: {len(cleaned_access)}")
state_count = cleaned_access.groupby("State").count()

#California
print(state_count["MarketName"].max())
# Puerto Rico
print(state_count["MarketName"].min())
#Average per State
print(f'Average Number of Farmers Markets: {state_count["MarketName"].mean()}')
print(f'Median Number of Farmers Markets: {state_count["MarketName"].median()}')



state_count.sort_values("MarketName")
# Out:
# Total Farmers Markets: 7650
# 713
# 10
# Average Number of Farmers Markets: 150.0
# Median Number of Farmers Markets: 116.0
#                 MarketName  City  County  WIC  WICcash  SFMNP  SNAP  \
# State
# Puerto Rico             10    10      10   10       10     10    10
# Alaska                  29    29      29   29       29     29    29
# Rhode Island            29    29      29   29       29     29    29
# Delaware                31    31      31   31       31     31    31
# Utah                    34    34      34   34       34     34    34
# South Dakota            34    34      34   34       34     34    34
# Nevada                  35    35      35   35       35     35    35
# Wyoming                 45    45      45   45       45     45    45
# Oklahoma                55    55      55   55       55     55    55
# Idaho                   58    58      58   58       58     58    58
# North Dakota            59    59      59   59       59     59    59
# New Mexico              64    64      64   64       64     64    64
# Montana                 67    67      67   67       67     67    67
# Hawaii                  68    68      68   68       68     68    68
# Louisiana               70    70      70   70       70     70    70
# Mississippi             73    73      73   73       73     73    73
# Vermont                 75    75      75   75       75     75    75
# West Virginia           77    77      77   77       77     77    77
# Arkansas                86    86      86   86       86     86    86
# Arizona                 87    87      87   87       87     87    87
# New Hampshire           87    87      87   87       87     87    87
# Maine                   88    88      88   88       88     88    88
# Nebraska                94    94      94   94       94     94    94
# Kansas                 105   105     105  105      105    105   105
# Tennessee              113   113     113  113      113    113   113
# Kentucky               116   116     116  116      116    116   116
# South Carolina         122   122     122  122      122    122   122
# Alabama                123   123     123  123      123    123   123
# Maryland               134   134     134  134      134    134   134
# Oregon                 135   135     135  135      135    135   135
# New Jersey             141   141     141  141      141    141   141
# Connecticut            142   142     142  142      142    142   142
# Colorado               148   148     148  148      148    148   148
# Georgia                151   151     151  151      151    151   151
# Washington             165   165     165  165      165    165   165
# Minnesota              173   173     173  173      173    173   173
# Indiana                180   180     180  180      180    180   180
# Virginia               184   184     184  184      184    184   184
# Iowa                   202   202     202  202      202    202   202
# Texas                  213   213     213  213      213    213   213
# North Carolina         225   225     225  225      225    225   225
# Missouri               228   228     228  228      228    228   228
# Florida                249   249     249  249      249    249   249
# Wisconsin              265   265     265  265      265    265   265
# Pennsylvania           279   279     279  279      279    279   279
# Ohio                   296   296     296  296      296    296   296
# Massachusetts          309   309     309  309      309    309   309
# Michigan               315   315     315  315      315    315   315
# Illinois               319   319     319  319      319    319   319
# New York               550   550     550  550      550    550   550
# California             713   713     713  713      713    713   713
#
#                 Income Per Capita  Median Household Income  \
# State
# Puerto Rico                    10                       10
# Alaska                         29                       29
# Rhode Island                   29                       29
# Delaware                       31                       31
# Utah                           34                       34
# South Dakota                   34                       34
# Nevada                         35                       35
# Wyoming                        45                       45
# Oklahoma                       55                       55
# Idaho                          58                       58
# North Dakota                   59                       59
# New Mexico                     64                       64
# Montana                        67                       67
# Hawaii                         68                       68
# Louisiana                      70                       70
# Mississippi                    73                       73
# Vermont                        75                       75
# West Virginia                  77                       77
# Arkansas                       86                       86
# Arizona                        87                       87
# New Hampshire                  87                       87
# Maine                          88                       88
# Nebraska                       94                       94
# Kansas                        105                      105
# Tennessee                     113                      113
# Kentucky                      116                      116
# South Carolina                122                      122
# Alabama                       123                      123
# Maryland                      134                      134
# Oregon                        135                      135
# New Jersey                    141                      141
# Connecticut                   142                      142
# Colorado                      148                      148
# Georgia                       151                      151
# Washington                    165                      165
# Minnesota                     173                      173
# Indiana                       180                      180
# Virginia                      184                      184
# Iowa                          202                      202
# Texas                         213                      213
# North Carolina                225                      225
# Missouri                      228                      228
# Florida                       249                      249
# Wisconsin                     265                      265
# Pennsylvania                  279                      279
# Ohio                          296                      296
# Massachusetts                 309                      309
# Michigan                      315                      315
# Illinois                      319                      319
# New York                      550                      550
# California                    713                      713
#
#                 Median Family Income  Population  Number of Households
# State
# Puerto Rico                       10          10                    10
# Alaska                            29          29                    29
# Rhode Island                      29          29                    29
# Delaware                          31          31                    31
# Utah                              34          34                    34
# South Dakota                      34          34                    34
# Nevada                            35          35                    35
# Wyoming                           45          45                    45
# Oklahoma                          55          55                    55
# Idaho                             58          58                    58
# North Dakota                      59          59                    59
# New Mexico                        64          64                    64
# Montana                           67          67                    67
# Hawaii                            68          68                    68
# Louisiana                         70          70                    70
# Mississippi                       73          73                    73
# Vermont                           75          75                    75
# West Virginia                     77          77                    77
# Arkansas                          86          86                    86
# Arizona                           87          87                    87
# New Hampshire                     87          87                    87
# Maine                             88          88                    88
# Nebraska                          94          94                    94
# Kansas                           105         105                   105
# Tennessee                        113         113                   113
# Kentucky                         116         116                   116
# South Carolina                   122         122                   122
# Alabama                          123         123                   123
# Maryland                         134         134                   134
# Oregon                           135         135                   135
# New Jersey                       141         141                   141
# Connecticut                      142         142                   142
# Colorado                         148         148                   148
# Georgia                          151         151                   151
# Washington                       165         165                   165
# Minnesota                        173         173                   173
# Indiana                          180         180                   180
# Virginia                         184         184                   184
# Iowa                             202         202                   202
# Texas                            213         213                   213
# North Carolina                   225         225                   225
# Missouri                         228         228                   228
# Florida                          249         249                   249
# Wisconsin                        265         265                   265
# Pennsylvania                     279         279                   279
# Ohio                             296         296                   296
# Massachusetts                    309         309                   309
# Michigan                         315         315                   315
# Illinois                         319         319                   319
# New York                         550         550                   550
# California                       713         713                   713

# %%
cleaned_access_income = round(cleaned_access.groupby("State").mean(),2)
cleaned_access_income = cleaned_access_income[["Median Household Income","Income Per Capita"]].reset_index()
cleaned_access_income.head()
# Out:
#         State  Median Household Income  Income Per Capita
# 0     Alabama                 54566.32           28005.36
# 1      Alaska                 71762.55           33145.07
# 2     Arizona                 49382.46           25615.11
# 3    Arkansas                 49488.14           25989.30
# 4  California                 61916.12           30813.53

# %%
cleaned_states = cleaned_access.groupby("State").count().reset_index()
cleaned_states = cleaned_states[["State","MarketName"]]
cleaned_states.head()
# Out:
#         State  MarketName
# 0     Alabama         123
# 1      Alaska          29
# 2     Arizona          87
# 3    Arkansas          86
# 4  California         713

# %% [markdown]
# ## No Food Assistance Programs

# %%
support_none_df = cleaned_access.loc[(cleaned_access["WIC"] == "N") & 
                   (cleaned_access ["WICcash"] == "N") &
                   (cleaned_access ["SFMNP"] == "N") &
                   (cleaned_access ["SNAP"] == "N"),:]
support_none_df.head()
# Out:
#                                         MarketName            City     County  \
# 2    Caledonia Farmers Market Association - Winter   St. Johnsbury  Caledonia
# 6                      Lyndonville Farmers' Market     Lyndonville  Caledonia
# 10  Case Western Reserve University Farmers Market      Cleveland    Cuyahoga
# 11                 Coventry Village Farmers Market   Cleveland Hts   Cuyahoga
# 14             First Baptist Church Farmers Market  Shaker Heights   Cuyahoga
#
#       State WIC WICcash SFMNP SNAP  Income Per Capita  \
# 2   Vermont   N       N     N    N              23584
# 6   Vermont   N       N     N    N              23584
# 10     Ohio   N       N     N    N              27423
# 11     Ohio   N       N     N    N              27423
# 14     Ohio   N       N     N    N              27423
#
#     Median Household Income  Median Family Income  Population  \
# 2                     45395                 54941       31157
# 6                     45395                 54941       31157
# 10                    43804                 59745     1272533
# 11                    43804                 59745     1272533
# 14                    43804                 59745     1272533
#
#     Number of Households
# 2                  12491
# 6                  12491
# 10                534476
# 11                534476
# 14                534476

# %%
none_states = support_none_df.groupby("State").count().reset_index()
none_states = none_states[["State","MarketName"]]
none_states.head()
# Out:
#         State  MarketName
# 0     Alabama          58
# 1      Alaska          13
# 2     Arizona          42
# 3    Arkansas          52
# 4  California         308

# %% [markdown]
# ## All 3 Food Assistance Programs

# %%
support_all_df = cleaned_access.loc[(cleaned_access["WIC"] == "Y") & 
                   (cleaned_access ["WICcash"] == "Y") &
                   (cleaned_access ["SFMNP"] == "Y") &
                   (cleaned_access ["SNAP"] == "Y"),:]
support_all_df.head()
# Out:
#                                            MarketName        City     County  \
# 4                            Hardwick Farmers' Market    Hardwick  Caledonia
# 12                  Downtown Cleveland Farmers Market   Cleveland   Cuyahoga
# 16                         Gateway105 Farmers' Market  Cleveland    Cuyahoga
# 18                                  Gordon SQ. Market   Cleveland   Cuyahoga
# 20  Lakewood Earth and Food (LEAF) Community Farme...    Lakewood   Cuyahoga
#
#       State WIC WICcash SFMNP SNAP  Income Per Capita  \
# 4   Vermont   Y       Y     Y    Y              23584
# 12     Ohio   Y       Y     Y    Y              27423
# 16     Ohio   Y       Y     Y    Y              27423
# 18     Ohio   Y       Y     Y    Y              27423
# 20     Ohio   Y       Y     Y    Y              27423
#
#     Median Household Income  Median Family Income  Population  \
# 4                     45395                 54941       31157
# 12                    43804                 59745     1272533
# 16                    43804                 59745     1272533
# 18                    43804                 59745     1272533
# 20                    43804                 59745     1272533
#
#     Number of Households
# 4                  12491
# 12                534476
# 16                534476
# 18                534476
# 20                534476

# %%
all_states = support_all_df.groupby("State").count().reset_index()
all_states = all_states[["State","MarketName"]]
all_states.head()
# Out:
#         State  MarketName
# 0     Alabama           4
# 1      Alaska           2
# 2     Arizona          25
# 3    Arkansas           4
# 4  California          93

# %% [markdown]
# ## At Least 1 of 3 Food Assistance Programs

# %%
support_some_df = cleaned_access.loc[(cleaned_access["WIC"] == "Y") | 
                   (cleaned_access ["WICcash"] == "Y") |
                   (cleaned_access ["SFMNP"] == "Y") |
                   (cleaned_access ["SNAP"] == "Y"),:]

# %%
some_states = support_some_df.groupby("State").count().reset_index()
some_states = some_states[["State","MarketName"]]
some_states.head()
# Out:
#         State  MarketName
# 0     Alabama          65
# 1      Alaska          16
# 2     Arizona          45
# 3    Arkansas          34
# 4  California         405

# %% [markdown]
# # Farmers Market Analysis

# %%
print(f"Of the {len(cleaned_access)} farmers markets we have noted, {len(support_none_df)} do not have any food assistance programs, {len(support_all_df)} has all four noted food assistance programs and {len(support_some_df)} has at least one of the three food assistance programs available.")
# Out:
# Of the 7650 farmers markets we have noted, 3912 do not have any food assistance programs, 622 has all four noted food assistance programs and 3738 has at least one of the three food assistance programs available.

# %%
round((3912/7650)*100,2)
# Out:
# 51.14

# %%
round((3738/7650)*100,2)
# Out:
# 48.86

# %%
food_assistance_count = pd.merge(cleaned_states,none_states, how = "outer", on ="State")
food_assistance_count = food_assistance_count.rename(columns={
    "MarketName_x":"Total Markets",
    "MarketName_y": "No Programs"
})
food_assistance_count = pd.merge(food_assistance_count,all_states,how = "outer", on ="State" )
food_assistance_count = food_assistance_count.rename(columns={
    "MarketName":"All Programs",
})
food_assistance_count = pd.merge(food_assistance_count,some_states,how = "outer", on ="State" )
food_assistance_count = food_assistance_count.rename(columns={
    "MarketName":"One or More Program(s)",
})
food_assistance_count["All Programs"] = food_assistance_count["All Programs"].fillna(0).astype(int)
food_assistance_count["One or More Program(s)"] = food_assistance_count["One or More Program(s)"].fillna(0).astype(int)
food_assistance_count = pd.merge(food_assistance_count,cleaned_access_income,how = "outer", on ="State" )
food_assistance_count = food_assistance_count[["State","All Programs","One or More Program(s)","No Programs","Total Markets","Median Household Income","Income Per Capita"]]
food_assistance_count["All Program %"] = round((food_assistance_count["All Programs"]/food_assistance_count["Total Markets"])*100,2)
food_assistance_count["FA Program %"] = round((food_assistance_count["One or More Program(s)"]/food_assistance_count["Total Markets"])*100,2)
food_assistance_count["No Program %"] = round((food_assistance_count["No Programs"]/food_assistance_count["Total Markets"])*100,2)
food_assistance_count.head()
# Out:
#         State  All Programs  One or More Program(s)  No Programs  \
# 0     Alabama             4                      65           58
# 1      Alaska             2                      16           13
# 2     Arizona            25                      45           42
# 3    Arkansas             4                      34           52
# 4  California            93                     405          308
#
#    Total Markets  Median Household Income  Income Per Capita  All Program %  \
# 0            123                 54566.32           28005.36           3.25
# 1             29                 71762.55           33145.07           6.90
# 2             87                 49382.46           25615.11          28.74
# 3             86                 49488.14           25989.30           4.65
# 4            713                 61916.12           30813.53          13.04
#
#    FA Program %  No Program %
# 0         52.85         47.15
# 1         55.17         44.83
# 2         51.72         48.28
# 3         39.53         60.47
# 4         56.80         43.20

# %% [markdown]
# ## Farmers Markets with Food Assistance Programs Available by State

# %%
food_assistance_sort = food_assistance_count[["State","One or More Program(s)","No Programs"]]
food_assistance_plot = food_assistance_sort.plot(kind="bar", figsize=(20,5))
food_assistance_plot.set_xticklabels(food_assistance_sort["State"], rotation=60)
plt.title("Farmers Markets with Food Assistance Programs Available by State",size= 14)
plt.xlabel("State",size= 14)
plt.ylabel("Number of Farmers Markets",size= 14)
plt.tight_layout()
plt.grid()
plt.savefig("./Priya's Resources/Charts/Farmers Markets with Food Assistance Programs.png")
plt.show()

# %%
no_assistance_count = food_assistance_count.loc[food_assistance_count["No Program %"] > 50,["State","Income Per Capita","Median Household Income","All Program %","FA Program %","No Program %"]]
no_assistance_count.head()
# Out:
#          State  Income Per Capita  Median Household Income  All Program %  \
# 3     Arkansas           25989.30                 49488.14           4.65
# 5     Colorado           31169.53                 57917.14           0.00
# 6  Connecticut           37362.15                 70146.07           7.75
# 8      Florida           28078.39                 50314.73           0.80
# 9      Georgia           27952.40                 53708.13           1.32
#
#    FA Program %  No Program %
# 3         39.53         60.47
# 5         39.19         60.81
# 6         33.80         66.20
# 8         24.90         75.10
# 9         39.74         60.26

# %%
some_assistance_count = food_assistance_count.loc[food_assistance_count["FA Program %"] > 50,["State","Income Per Capita","Median Household Income","All Program %","FA Program %","No Program %"]]
some_assistance_count.head()
# Out:
#         State  Income Per Capita  Median Household Income  All Program %  \
# 0     Alabama           28005.36                 54566.32           3.25
# 1      Alaska           33145.07                 71762.55           6.90
# 2     Arizona           25615.11                 49382.46          28.74
# 4  California           30813.53                 61916.12          13.04
# 7    Delaware           34687.94                 73143.52           0.00
#
#    FA Program %  No Program %
# 0         52.85         47.15
# 1         55.17         44.83
# 2         51.72         48.28
# 4         56.80         43.20
# 7         51.61         48.39

# %%
food_assistance_count.plot(kind = "scatter", x = "Median Household Income",y = "Income Per Capita")
correlation = st.pearsonr(food_assistance_count["Income Per Capita"],food_assistance_count["Median Household Income"])[0]
print(f"The correlation coefficient between the Income Per Capita and Median Household Income per state is {round(correlation,4)}.")
plt.savefig("./Priya's Resources/Charts/Correlation - Median Household and Income Per Capita.png")
# Out:
# The correlation coefficient between the Income Per Capita and Median Household Income per state is 0.9387.

# %%
food_assistance_count.plot(kind = "scatter", x = "Income Per Capita",y = "No Program %")
plt.title("Income Per Capita with No Programs in Most Markets")
plt.ylim(50,105)
(slope, intercept, rvalue, pvalue, stderr) = linregress(food_assistance_count["Income Per Capita"],food_assistance_count["No Program %"])
regress_values = food_assistance_count["Income Per Capita"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(food_assistance_count["Income Per Capita"],regress_values,"r-")
plt.annotate(line_eq,(15000,55),fontsize=16,color="red")
plt.tight_layout()
plt.savefig("./Priya's Resources/Charts/Income Per Capita of Markets with No Programs.png")
plt.show()
correlation = st.pearsonr(food_assistance_count["Income Per Capita"],food_assistance_count["No Program %"])[0]
print(f"The correlation coefficient between the Income Per Capita in a state and states in which farmers markets have no financial assistance programs is {round(correlation,4)}.")
# Out:
# The correlation coefficient between the Income Per Capita in a state and states in which farmers markets have no financial assistance programs is -0.1972.

# %%
food_assistance_count.plot(kind = "scatter", x = "Income Per Capita",y = "FA Program %")
plt.title("Income Per Capita with 1 or More Programs in Most Markets")
# plt.ylim(50,105)
(slope, intercept, rvalue, pvalue, stderr) = linregress(food_assistance_count["Income Per Capita"],food_assistance_count["FA Program %"])
regress_values = food_assistance_count["Income Per Capita"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(food_assistance_count["Income Per Capita"],regress_values,"r-")
plt.annotate(line_eq,(15000,45),fontsize=16,color="red")
plt.tight_layout()
plt.savefig("./Priya's Resources/Charts/Income Per Capita of Markets with 1 or More Programs.png")
plt.show()
correlation = st.pearsonr(food_assistance_count["Income Per Capita"],food_assistance_count["FA Program %"])[0]
print(f"The correlation coefficient between the Income Per Capita in a state and states in which farmers markets have at least one financial assistance program is {round(correlation,4)}.")
# Out:
# The correlation coefficient between the Income Per Capita in a state and states in which farmers markets have at least one financial assistance program is 0.1972.

# %%
food_assistance_count.plot(kind = "scatter", x = "Income Per Capita",y = "Total Markets",figsize=(10,10))
plt.title("Number of Farmers Markets by Income Per Capita of a State")
plt.savefig("./Priya's Resources/Charts/Total Farmers Markets v Insome Per Capita.png")
correlation = st.pearsonr(food_assistance_count["Income Per Capita"],food_assistance_count["Total Markets"])[0]
print(f"The correlation coefficient between the Income Per Capita and total farmers markets per state is {round(correlation,4)}.")
# Out:
# The correlation coefficient between the Income Per Capita and total farmers markets per state is 0.2357.

# %%
food_assistance_count.plot(kind = "bar", x = "State",y = "Income Per Capita",figsize=(20,5))
print(f"{food_assistance_count['Income Per Capita'].max()}")
print(f"{food_assistance_count['Income Per Capita'].min()}")
# Out:
# 37362.15
# 15210.7

# %% [markdown]
# # Food Deserts Data Overview / Cleaning

# %%
desert_df.head()
# Out:
#    CensusTract    State   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# 0   1001020100  Alabama  Autauga      1     1912      693                  0
# 1   1001020200  Alabama  Autauga      1     2170      743                  0
# 2   1001020300  Alabama  Autauga      1     3373     1256                  0
# 3   1001020400  Alabama  Autauga      1     4386     1722                  0
# 4   1001020500  Alabama  Autauga      1    10766     4082                  0
#
#    NUMGQTRS  PCTGQTRS  LILATracts_1And10    ...      TractSeniors  TractWhite  \
# 0         0  0.000000                  0    ...               221        1622
# 1       181  0.083410                  0    ...               214         888
# 2         0  0.000000                  0    ...               439        2576
# 3         0  0.000000                  0    ...               904        4086
# 4       181  0.016812                  0    ...              1126        8666
#
#    TractBlack  TractAsian  TractNHOPI  TractAIAN  TractOMultir  TractHispanic  \
# 0         217          14           0         14            45             44
# 1        1217           5           0          5            55             75
# 2         647          17           5         11           117             87
# 3         193          18           4         11            74             85
# 4        1437         296           9         48           310            355
#
#    TractHUNV  TractSNAP
# 0         26        112
# 1         87        202
# 2        108        120
# 3         19         82
# 4        198        488
#
# [5 rows x 147 columns]

# %%
print(f'Total Number of Tracts: {desert_df["POP2010"].count()}')
print(f'Tracts considered in food deserts: {desert_df["LA1and10"].sum()}')
print(f'Percentage of Tracts in food deserts: {round((desert_df["LA1and10"].sum()/desert_df["LA1and10"].count())*100,2)}%')
print(f'Total Population in dataset: {desert_df["POP2010"].sum()}')
print(f'Estimated Population in food deserts: {round(desert_df["POP2010"].sum()*((desert_df["LA1and10"].sum()/desert_df["LA1and10"].count())),)}')
# Out:
# Total Number of Tracts: 72864
# Tracts considered in food deserts: 27527
# Percentage of Tracts in food deserts: 37.78%
# Total Population in dataset: 308745538
# Estimated Population in food deserts: 116639746.0

# %%
desert_var
# Out:
#                     Field                                           LongName  \
# 0             CensusTract                                       Census tract
# 1                   State                                              State
# 2                  County                                             County
# 3                   Urban                                        Urban tract
# 4                 POP2010                            Population, tract total
# 5                 OHU2010                               Housing units, total
# 6       GroupQuartersFlag              Group quarters, tract with high share
# 7                NUMGQTRS  Group quarters, tract population residing in, ...
# 8                PCTGQTRS  Group quarters, tract population residing in, ...
# 9       LILATracts_1And10  Low income and low access tract measured at 1 ...
# 10   LILATracts_halfAnd10  Low income and low access tract measured at 1/...
# 11      LILATracts_1And20  Low income and low access tract measured at 1 ...
# 12     LILATracts_Vehicle  Low income and low access tract using vehicle ...
# 13               HUNVFlag      Vehicle access, tract with low vehicle access
# 14        LowIncomeTracts                                   Low income tract
# 15            PovertyRate                                 Tract poverty rate
# 16     MedianFamilyIncome                         Tract median family income
# 17               LA1and10  Low access tract at 1 mile for urban areas and...
# 18            LAhalfand10  Low access tract at 1/2 mile for urban areas a...
# 19               LA1and20  Low access tract at 1 mile for urban areas and...
# 20          LATracts_half                       Low access tract at 1/2 mile
# 21              LATracts1                         Low access tract at 1 mile
# 22             LATracts10                       Low access tract at 10 miles
# 23             LATracts20                       Low access tract at 20 miles
# 24     LATractsVehicle_20  Low access tract using vehicle access and at 2...
# 25              LAPOP1_10  Low access, population at 1 mile for urban are...
# 26             LAPOP05_10  Low access, population at 1/2 mile for urban a...
# 27              LAPOP1_20  Low access, population at 1 mile for urban are...
# 28             LALOWI1_10  Low access, low-income population at 1 mile fo...
# 29            LALOWI05_10  Low access, low-income population at 1/2 mile ...
# ..                    ...                                                ...
# 117             lawhite20   Low access, White population at 20 miles, number
# 118        lawhite20share    Low access, White population at 20 miles, share
# 119             lablack20  Low access, Black or African American populati...
# 120        lablack20share  Low access, Black or African American populati...
# 121             laasian20   Low access, Asian population at 20 miles, number
# 122        laasian20share    Low access, Asian population at 20 miles, share
# 123             lanhopi20  Low access, Native Hawaiian and Other Pacific ...
# 124        lanhopi20share  Low access, Native Hawaiian and Other Pacific ...
# 125              laaian20  Low access, American Indian and Alaska Native ...
# 126         laaian20share  Low access, American Indian and Alaska Native ...
# 127           laomultir20  Low access, Other/Multiple race population at ...
# 128      laomultir20share  Low access, Other/Multiple race population at ...
# 129              lahisp20  Low access, Hispanic or Latino population at 2...
# 130         lahisp20share  Low access, Hispanic or Latino population at 2...
# 131              lahunv20  Vehicle access, housing units without and low ...
# 132         lahunv20share  Vehicle access, housing units without and low ...
# 133              lasnap20  Low access, housing units receiving SNAP benef...
# 134         lasnap20share  Low access, housing units receiving SNAP benef...
# 135             TractLOWI                Tract low-income population, number
# 136             TractKids                    Tract children age 0-17, number
# 137          TractSeniors                      Tract seniors age 65+, number
# 138            TractWhite                     Tract White population, number
# 139            TractBlack  Tract Black or African American population, nu...
# 140            TractAsian                     Tract Asian population, number
# 141            TractNHOPI  Tract Native Hawaiian and Other Pacific Island...
# 142             TractAIAN  Tract American Indian and Alaska Native popula...
# 143          TractOMultir       Tract Other/Multiple race population, number
# 144         TractHispanic        Tract Hispanic or Latino population, number
# 145             TractHUNV      Tract housing units without a vehicle, number
# 146             TractSNAP  Tract housing units receiving SNAP benefits, n...
#
#                                            Description
# 0                                  Census tract number
# 1                                           State name
# 2                                          County name
# 3                                 Flag for urban tract
# 4                    Population count from 2010 census
# 5         Occupied housing unit count from 2010 census
# 6                           Flag for tract where >=67%
# 7    Count of tract population residing in group qu...
# 8    Percent of tract population residing in group ...
# 9    Flag for food desert when considering low acce...
# 10   Flag for food desert when considering low acce...
# 11   Flag for food desert when considering low acce...
# 12   Flag for food desert when considering vehicle ...
# 13   Flag for tract where >= 100 of households do n...
# 14                           Flag for low income tract
# 15   Share of the tract population living with inco...
# 16                          Tract median family income
# 17   Flag for low access tract at 1 mile for urban ...
# 18   Flag for low access tract at 1/2 mile for urba...
# 19   Flag for low access tract at 1 mile for urban ...
# 20   Flag for low access tract when considering 1/2...
# 21   Flag for low access tract when considering 1 m...
# 22   Flag for low access tract when considering 10 ...
# 23   Flag for low access tract when considering 20 ...
# 24   Flag for tract where >= 100 of households do n...
# 25   Population count beyond 1 mile for urban areas...
# 26   Population count beyond 1/2 mile for urban are...
# 27   Population count beyond 1 mile for urban areas...
# 28   Low income population count beyond 1 mile for ...
# 29   Low income population count beyond 1/2 mile fo...
# ..                                                 ...
# 117  White population count beyond 20 miles from su...
# 118  Share of tract population that are white beyon...
# 119  Black or African American population count bey...
# 120  Share of tract population that are Black or Af...
# 121  Asian population count beyond 20 miles from su...
# 122  Share of tract population that are Asian beyon...
# 123  Native Hawaiian or Other Pacific Islander popu...
# 124  Share of tract population that are Native Hawa...
# 125  American Indian or Alaska Native population co...
# 126  Share of tract population that are American In...
# 127  Other/Multiple race population count beyond 20...
# 128  Share of tract population that are Other/Multi...
# 129  Hispanic or Latino ethnicity population count ...
# 130  Share of tract population that are of Hispanic...
# 131  Housing units without vehicle count beyond 20 ...
# 132  Share of tract housing units that are without ...
# 133  Housing units receiving SNAP benefits count be...
# 134  Share of tract housing units receiving SNAP be...
# 135     Total count of low-income population in tract
# 136         Total count of children age 0-17 in tract
# 137           Total count of seniors age 65+ in tract
# 138          Total count of White population in tract
# 139  Total count of Black or African American popul...
# 140          Total count of Asian population in tract
# 141  Total count of Native Hawaiian and Other Pacif...
# 142  Total count of American Indian and Alaska Nati...
# 143  Total count of Other/Multiple race population ...
# 144  Total count of Hispanic or Latino population i...
# 145  Total count of housing units without a vehicle...
# 146  Total count of housing units receiving SNAP be...
#
# [147 rows x 3 columns]

# %%
food_desert_df = desert_df[["State","County","Urban","POP2010","PovertyRate","MedianFamilyIncome","TractSNAP","LA1and10"]]
poverty = round(food_desert_df[["State","PovertyRate","TractSNAP"]].groupby("State").mean(),2)
poverty = poverty.reset_index()

# %%
food_desert_df.groupby("State").sum().sort_values("LA1and10")
# Out:
#                       Urban   POP2010  PovertyRate  MedianFamilyIncome  \
# State
# District of Columbia    179    601723       3529.1            17593246
# Vermont                  50    625741       2276.8            12450101
# Wyoming                  69    563626       1621.2             9285167
# Maine                   106   1328361       5208.9            21291267
# Alaska                   85    710231       1875.7            13381966
# Delaware                170    897934       2760.9            15922228
# Rhode Island            217   1052567       3614.5            17860013
# North Dakota             87    672591       2477.4            14656652
# New Hampshire           154   1316470       2810.9            23522182
# Hawaii                  270   1360301       3569.6            25323687
# Montana                 110    989415       4399.6            15898894
# South Dakota             94    814180       3308.5            13919656
# Idaho                   170   1567582       4902.2            16838717
# West Virginia           217   1852994       9486.0            25218997
# Nebraska                349   1826341       7201.6            35172479
# Nevada                  609   2700551      10937.5            42457233
# Utah                    498   2763885       7921.9            40590024
# New Mexico              344   2059179      10360.7            28386889
# Oregon                  597   3831074      13947.1            53220620
# Kentucky                557   4339367      22425.5            60782613
# Arkansas                335   2915918      13960.2            35122700
# Iowa                    458   3046355      10968.0            53399367
# Mississippi             329   2967297      16311.8            31376287
# Kansas                  508   2853118      11450.3            49045181
# Connecticut             706   3574097       9754.5            75292686
# Oklahoma                674   3751351      19101.5            59933190
# Colorado                977   5029196      16882.7            93453834
# Alabama                 644   4779736      25020.8            62676154
# South Carolina          655   4625364      21576.0            60790000
# Louisiana               816   4533372      24741.8            63194853
# Maryland               1181   5773552      15358.9           125167021
# Wisconsin               927   5686986      20766.5            91239271
# Indiana                1043   6483802      27000.7            86347274
# Massachusetts          1316   6547629      18840.8           127345224
# Washington             1122   6724540      20214.6           108386015
# Minnesota               907   5303925      16621.2           100021371
# Missouri                931   5988927      24187.8            84062882
# Arizona                1293   6392017      28213.7            92612299
# Tennessee               896   6346105      28539.6            83556932
# Virginia               1368   8001024      23569.3           156951063
# New Jersey             1853   8791894      23065.4           178764331
# New York               4183  19378102      77912.3           367517076
# North Carolina         1351   9535483      39996.0           130573319
# Michigan               2007   9883640      51852.9           166136894
# Georgia                1319   9687653      40303.8           117504926
# Illinois               2625  12830632      50863.4           224317880
# Pennsylvania           2459  12702379      47269.0           218519518
# Ohio                   2283  11536504      55564.5           175942449
# Florida                3627  18801310      72219.6           250764960
# California             7352  37253956     132916.6           604648002
# Texas                  4095  25145561      97453.8           334910884
#
#                       TractSNAP  LA1and10
# State
# District of Columbia      37777         9
# Vermont                   35781        39
# Wyoming                   14036        79
# Maine                     95403        86
# Alaska                    26130        88
# Delaware                  43114        94
# Rhode Island              63848        98
# North Dakota              23297       112
# New Hampshire             42443       122
# Hawaii                    48933       124
# Montana                   43869       137
# South Dakota              36249       139
# Idaho                     74198       157
# West Virginia            117503       174
# Nebraska                  66947       238
# Nevada                   114982       239
# Utah                      81055       263
# New Mexico               116864       269
# Oregon                   290204       294
# Kentucky                 294172       328
# Arkansas                 167466       341
# Iowa                     142880       348
# Mississippi              196525       348
# Kansas                   106372       373
# Connecticut              157477       391
# Oklahoma                 202916       466
# Colorado                 171194       488
# Alabama                  291592       490
# South Carolina           272687       494
# Louisiana                281819       494
# Maryland                 224151       496
# Wisconsin                290441       523
# Indiana                  312260       603
# Massachusetts            313989       615
# Washington               376467       617
# Minnesota                185637       619
# Missouri                 322657       638
# Arizona                  323640       656
# Tennessee                431220       658
# Virginia                 289545       727
# New Jersey               272130       744
# New York                1096111       907
# North Carolina           539264       925
# Michigan                 653958       979
# Georgia                  539005       982
# Illinois                 599393       994
# Pennsylvania             619281      1065
# Ohio                     683427      1211
# Florida                 1032766      1833
# California              1102588      1968
# Texas                   1218803      2445

# %%
poverty.plot(kind = "scatter",x = "PovertyRate", y = "TractSNAP")
plt.xlabel("Poverty Rate %")
plt.ylabel("Housing Units w/SNAP Benefits")
plt.title("SNAP Benefits versus the Poverty Rate by State")
(slope, intercept, rvalue, pvalue, stderr) = linregress(poverty["PovertyRate"],poverty["TractSNAP"])
regress_values = poverty["PovertyRate"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(poverty["PovertyRate"],regress_values,"r-")
plt.annotate(line_eq,(17,105),fontsize=16,color="red")
plt.savefig("./Priya's Resources/Charts/SNAP Benefits versus the Poverty Rate by State.png")

correlation = st.pearsonr(poverty["PovertyRate"],poverty["TractSNAP"])[0]
round(correlation,2)
# Out:
# 0.69

# %%
snap_support = cleaned_access.loc[(cleaned_access ["SNAP"] == "Y"),:]
snap_states = snap_support.groupby("State").count().reset_index()
snap_states = snap_states[["State","SNAP"]].rename(columns={"SNAP":"MarketSNAP"})
snap_states.head()
# Out:
#         State  MarketSNAP
# 0     Alabama          24
# 1      Alaska           7
# 2     Arizona          35
# 3    Arkansas          22
# 4  California         324

# %%
poverty_assistance_df = pd.merge(poverty,snap_states,how = "outer",on = "State")
poverty_assistance_df = poverty_assistance_df.dropna().sort_values("PovertyRate")

# %%
poverty_assistance_df.plot(kind = "scatter",x = "TractSNAP", y = "MarketSNAP")
plt.xlabel("Housing Units")
plt.ylabel("Number of Markets")
plt.title("SNAP Benefits versus Markets with SNAP")
(slope, intercept, rvalue, pvalue, stderr) = linregress(poverty_assistance_df["TractSNAP"],poverty_assistance_df["MarketSNAP"])
regress_values = poverty_assistance_df["TractSNAP"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(poverty_assistance_df["TractSNAP"],regress_values,"r-")
plt.annotate(line_eq,(100,115),fontsize=16,color="red")
plt.savefig("./Priya's Resources/Charts/SNAP Benefits versus Markets with SNAP.png")
plt.show()


correlation = st.pearsonr(poverty_assistance_df["TractSNAP"],poverty_assistance_df["MarketSNAP"])[0]
round(correlation,2)
# Out:
# 0.05
